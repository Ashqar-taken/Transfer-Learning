# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Torch CUDA version:", torch.version.cuda)
# Out:
# Torch version: 2.2.2
# CUDA available: False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 print("Torch version:", torch.__version__)
#       3 print("CUDA available:", torch.cuda.is_available())
# ----> 4 print("Torch CUDA version:", torch.version.cu)
#
# AttributeError: module 'torch.version' has no attribute 'cu'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\admin\.conda\envs\dl_env\python.exe
